# %%
import requests

res = requests.get("https://prtimes.jp/sitemap-news.xml")
txt = res.text
print(txt[:1000])
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" xmlns:news="http://www.google.com/schemas/sitemap-news/0.9">
#   <url>
#     <loc>https://prtimes.jp/main/html/rd/p/000000014.000121694.html</loc>
#     <news:news>
#       <news:publication>
#         <news:name>PR TIMES</news:name>
#         <news:language>ja</news:language>
#       </news:publication>
#       <news:genres>PressRelease</news:genres>
#       <news:publication_date>2026-03-05T14:14:39+09:00</news:publication_date>
#       <news:title>ãã­ã³ãã£ã¢ãAIã¨ã¼ã¸ã§ã³ããåé¨ç£æ»ã®å¨å·¥ç¨ãèªå¾å®è¡ããé©æ°çã½ãªã¥ã¼ã·ã§ã³ãçºè¡¨</news:title>
#       <news:keywords>çµå¶ã»ã³ã³ãµã«ãã£ã³ã°,ãã­ã³ãã£ã¢,åé¨ç£æ»,AIããªãã³åé¨ç£æ»,ãã¸ã¿ã«ã¬ããã³ã¹,Front-IA Innovations,Frontier Advisory &amp; Consulting,AIã¨ã¼ã¸ã§ã³ã,Frontier Audit Agent,Frontier Audit Engine,Frontier Audit Academy</news:keywords>
# ...
